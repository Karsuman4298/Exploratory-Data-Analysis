# %% [markdown]
# <a href="https://colab.research.google.com/github/Karsuman4298/Exploratory-Data-Analysis/blob/main/Fake_news_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download clmentbisaillon/fake-and-real-news-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset
# License(s): CC-BY-NC-SA-4.0

# %%
# !unzip fake-and-real-news-dataset.zip
# Out:
# Archive:  fake-and-real-news-dataset.zip
# replace Fake.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import pandas as pd

# %%
df= pd.read_csv('Fake.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df["title"][0]
# Out:
# ' Donald Trump Sends Out Embarrassing New Year’s Eve Message; This is Disturbing'

# %%
df["text"][0]
# Out:
# 'Donald Trump just couldn t wish all Americans a Happy New Year and leave it at that. Instead, he had to give a shout out to his enemies, haters and  the very dishonest fake news media.  The former reality show star had just one job to do and he couldn t do it. As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year,  President Angry Pants tweeted.  2018 will be a great year for America! As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year. 2018 will be a great year for America!  Donald J. Trump (@realDonaldTrump) December 31, 2017Trump s tweet went down about as welll as you d expect.What kind of president sends a New Year s greeting like this despicable, petty, infantile gibberish? Only Trump! His lack of decency won t 
# ...

# %%
df["text"]=df["subject"]+ " : "+df["title"]+" "+df["text"]

# %%
df.drop(columns=["date","title","subject"],inplace=True)

# %%
df.head()
# Out:
#                                                 text
# 0  News :  Donald Trump Sends Out Embarrassing Ne...
# 1  News :  Drunk Bragging Trump Staffer Started R...
# 2  News :  Sheriff David Clarke Becomes An Intern...
# 3  News :  Trump Is So Obsessed He Even Has Obama...
# 4  News :  Pope Francis Just Called Out Donald Tr...

# %%
df["label"]=0

# %%
df.head()
# Out:
#                                                 text  label
# 0  News :  Donald Trump Sends Out Embarrassing Ne...      0
# 1  News :  Drunk Bragging Trump Staffer Started R...      0
# 2  News :  Sheriff David Clarke Becomes An Intern...      0
# 3  News :  Trump Is So Obsessed He Even Has Obama...      0
# 4  News :  Pope Francis Just Called Out Donald Tr...      0

# %%
df_true=pd.read_csv('True.csv')

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_true["text"]=df_true["subject"]+ " : "+df_true["title"]+" "+df_true["text"]

# %%
df_true.drop(columns=["date","title","subject"],inplace=True)

# %%
df_true.head()
# Out:
#                                                 text
# 0  politicsNews : As U.S. budget fight looms, Rep...
# 1  politicsNews : U.S. military to accept transge...
# 2  politicsNews : Senior U.S. Republican senator:...
# 3  politicsNews : FBI Russia probe helped by Aust...
# 4  politicsNews : Trump wants Postal Service to c...

# %%
df_true["label"]=1

# %%
df_true.head()
# Out:
#                                                 text  label
# 0  politicsNews : As U.S. budget fight looms, Rep...      1
# 1  politicsNews : U.S. military to accept transge...      1
# 2  politicsNews : Senior U.S. Republican senator:...      1
# 3  politicsNews : FBI Russia probe helped by Aust...      1
# 4  politicsNews : Trump wants Postal Service to c...      1

# %%
dataset=pd.concat([df,df_true],axis=0)

# %%
dataset.head()
# Out:
#                                                 text  label
# 0  News :  Donald Trump Sends Out Embarrassing Ne...      0
# 1  News :  Drunk Bragging Trump Staffer Started R...      0
# 2  News :  Sheriff David Clarke Becomes An Intern...      0
# 3  News :  Trump Is So Obsessed He Even Has Obama...      0
# 4  News :  Pope Francis Just Called Out Donald Tr...      0

# %%
df.shape
# Out:
# (23481, 2)

# %%
df_true.shape
# Out:
# (21417, 2)

# %%
dataset.shape
# Out:
# (44898, 2)

# %%
23481+21417
# Out:
# 44898

# %%
data=dataset.copy()

# %%
data
# Out:
#                                                     text  label
# 0      News :  Donald Trump Sends Out Embarrassing Ne...      0
# 1      News :  Drunk Bragging Trump Staffer Started R...      0
# 2      News :  Sheriff David Clarke Becomes An Intern...      0
# 3      News :  Trump Is So Obsessed He Even Has Obama...      0
# 4      News :  Pope Francis Just Called Out Donald Tr...      0
# ...                                                  ...    ...
# 21412  worldnews : 'Fully committed' NATO backs new U...      1
# 21413  worldnews : LexisNexis withdrew two products f...      1
# 21414  worldnews : Minsk cultural hub becomes haven f...      1
# 21415  worldnews : Vatican upbeat on possibility of P...      1
# 21416  worldnews : Indonesia to buy $1.14 billion wor...      1
#
# [44898 rows x 2 columns]

# %%
data=data.sample(frac=1,random_state=42).reset_index(drop=True)

# %%
data.sample(10)
# Out:
#                                                     text  label
# 17022  Middle-east : OUT IN THE OPEN: ‘9/11’ 15 Years...      0
# 32720  worldnews : U.S. jets fire flares to warn Russ...      1
# 20761  politicsNews : Trump on Twitter (Aug 16)- Manu...      1
# 9127   politicsNews : Thousands of students carry pro...      1
# 29628  politicsNews : U.S. appeals court questions sc...      1
# 10566  politicsNews : Iowa moves to cut Medicaid fund...      1
# 26423  News :  WATCH: Paul Ryan Reveals This Really W...      0
# 26578  Government News : DISGRACEFUL! Senator John Mc...      0
# 7874   politics : SHOCKER! Senator Diane Feinstein Ca...      0
# 22926  worldnews : Trump speaks with Palestinian lead...      1

# %%
data.head(10)
# Out:
#                                                 text  label
# 0  US_News : Ben Stein Calls Out 9th Circuit Cour...      0
# 1  politicsNews : Trump drops Steve Bannon from N...      1
# 2  politicsNews : Puerto Rico expects U.S. to lif...      1
# 3  News :  OOPS: Trump Just Accidentally Confirme...      0
# 4  politicsNews : Donald Trump heads for Scotland...      1
# 5  News :  Paul Ryan Responds To Dem’s Sit-In On ...      0
# 6  Government News : AWESOME! DIAMOND AND SILK Ri...      0
# 7  left-news : STAND UP AND CHEER! UKIP Party Lea...      0
# 8  worldnews : North Korea shows no sign it is se...      1
# 9  politicsNews : Trump signals willingness to ra...      1

# %%
data.to_csv('Fake_news.csv',index=False)

# %%
data.text[0]
# Out:
# 'US_News : Ben Stein Calls Out 9th Circuit Court: Committed a ‘Coup d’état’ Against the Constitution 21st Century Wire says Ben Stein, reputable professor from, Pepperdine University (also of some Hollywood fame appearing in TV shows and films such as Ferris Bueller s Day Off) made some provocative statements on Judge Jeanine Pirro s show recently. While discussing the halt that was imposed on President Trump s Executive Order on travel. Stein referred to the judgement by the 9th Circuit Court in Washington state as a  Coup d tat against the executive branch and against the constitution.  Stein went on to call the Judges in Seattle  political puppets  and the judiciary  political pawns. Watch the interview below for the complete statements and note the stark contrast to the rhetoric of the leftist media and pundits who neglect to note that no court has ever blocked any Presidential orders in immigration in the past or discuss the legal efficacy of the halt or the actual text of the E
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <cell line: 0>()
# ----> 1 data
#
# NameError: name 'data' is not defined
